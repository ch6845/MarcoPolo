# %%
import os
print(os.getcwd());os.chdir('/data01/ch6845/MarcoPolo/')
print(os.getcwd())
# Out:
# /data01/ch6845/MarcoPolo/experiments
# /data01/ch6845/MarcoPolo

# %%
import MarcoPolo.report as report

# %%
report.generate_report("datasets/extract/Kohinbulk_filtered",output_path="docs/hESC")
# Out:
# /home/ch6845/tools/miniconda3/envs/MarcoPolo/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ch6845/tools/miniconda3/envs/MarcoPolo/lib/python3.7/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ENSG00000198804 0
# 0.00%ENSG00000210082 0
# ENSG00000198712 0
# ENSG00000198938 0
# ENSG00000198727 0
# ENSG00000211459 0
# ENSG00000198899 0
# ENSG00000198886 0
# ENSG00000198763 0
# ENSG00000198888 0
# ENSG00000198786 0
# ENSG00000212907 0
# 0.68%ENSG00000225840 0
# ENSG00000274474 0
# ENSG00000183311 0
# ENSG00000223367 0
# ENSG00000226225 0
# ENSG00000235650 0
# ENSG00000096150 0
# ENSG00000273673 0
# 1.36%ENSG00000228253 0
# ENSG00000224078 0
# ENSG00000198695 0
# ENSG00000280831 0
# ENSG00000280858 0
# ENSG00000281344 0
# ENSG00000280800 0
# ENSG00000281181 0
# ENSG00000280614 0
# 3.40%ENSG00000281013 0
# ...

# %%
os.path.join('adssd','dsd')
# Out:
# 'adssd/dsd'
